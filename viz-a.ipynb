# %% [markdown]
# # Lab: Data Visualization

# %%
import pandas as pd
import seaborn as sns   
import matplotlib.pyplot as plt 
sns.set(color_codes=True) 
# %matplotlib inline 
auto = pd.read_csv('./Automobile.csv')
auto.head(10)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
# 5          2                161         audi       gas        std
# 6          1                158         audi       gas        std
# 7          1                168         audi       gas        std
# 8          1                158         audi       gas      turbo
# 9          2                192          bmw       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# ...

# %%
sns.distplot(auto['highway_mpg'])
# Out:
# /home/faisal/asac/data-visualization/.venv/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='highway_mpg', ylabel='Density'>

# %%
auto['city_mpg']
# Out:
# 0      21
# 1      21
# 2      19
# 3      24
# 4      18
#        ..
# 196    23
# 197    19
# 198    18
# 199    26
# 200    19
# Name: city_mpg, Length: 201, dtype: int64

# %%
sns.distplot(auto['city_mpg'], kde=False, rug=True);
# Out:
# /home/faisal/asac/data-visualization/.venv/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/faisal/asac/data-visualization/.venv/lib/python3.9/site-packages/seaborn/distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(auto['engine_size'], auto['horsepower'])
# Out:
# /home/faisal/asac/data-visualization/.venv/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(auto['engine_size'], auto['horsepower'], kind="hex")
# Out:
# /home/faisal/asac/data-visualization/.venv/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(auto[['normalized_losses', 'engine_size', 'horsepower']])

# %%
sns.countplot(auto['body_style'],hue=auto['fuel_type'])
# Out:
# /home/faisal/asac/data-visualization/.venv/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body_style', ylabel='count'>

# %%
sns.lmplot(y="horsepower", x="engine_size", data=auto)

# %%
sns.lmplot(y="horsepower", x="engine_size",hue="fuel_type", data=auto)

# %%
sns.distplot(tips['tip'])
sns.distplot(tips['total_bill']);
plt.legend('ABCDEF', ncol=2, loc='upper right');

# %%
with sns.axes_style('white'):
    sns.jointplot("tip", "total_bill", tips, kind='kde');
    plt.legend('ABCDEF', ncol=2, loc='upper right');

# %%
with sns.axes_style('white'):
    sns.jointplot("tip", "total_bill", tips, kind='hex');
    plt.legend('ABCDEF', ncol=2, loc='upper right');

# %% [markdown]
# ## Summary:
#
# - 1- How to use the different libraries like Pandas. matplotlib, numpy, seaborn.
# - 2- how to visualize the data.
# - 3- how to use different plotting to visualize the data.
# - 4 - how to deal with analysis the data using Pandas library.
# - 5 - How to load data file(s) using Pandas.
# - 6 - How to convert a variable to a different data type.
# - 7 - How to transpose a Data set or dataframe using Pandas.
# - 8 - How to sort a Pandas DataFrame.
# - 9 - How to group variables in Pandas to calculate count, average, sum.
# - 10 - How to summarize the distribution of variables using bar charts, histograms, and box and whisker plots.
# - 11 - How to summarize relationships using line plots and scatter plots.
# - 12 - How to compare the distribution and relationships of variables for different class values on the same plot.
